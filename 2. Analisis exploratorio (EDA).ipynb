# %% [markdown]
# **Proyecto TikTok**
# **Curso 3 - Más allá de los números: Traducir los datos en información**

# %% [markdown]
# Tu equipo de datos de TikTok está todavía en las primeras etapas de su último proyecto. Hasta ahora, has completado una propuesta de proyecto y has utilizado Python para inspeccionar y organizar el conjunto de datos de TikTok.
#
# Orion Rainier, un científico de datos en TikTok, está satisfecho con el trabajo que ya has completado y está solicitando tu ayuda con algunos análisis exploratorios de datos (EDA) y visualización de datos. El equipo de gestión pidió ver un cuaderno Python que muestre la estructuración y limpieza de datos, así como cualquier visualización matplotlib/seaborn trazada para ayudarnos a entender los datos. Como mínimo, incluya un gráfico que compare el recuento de reclamaciones con el de opiniones, así como gráficos de caja de las variables más importantes (como "duración del vídeo", "recuento de me gusta en el vídeo", "recuento de comentarios en el vídeo" y "recuento de visualizaciones del vídeo") para comprobar si hay valores atípicos. Incluye también un desglose de los recuentos de "estado de prohibición del autor".
#
# Además, el equipo directivo ha pedido recientemente a todos los EDA que incluyan visualizaciones de Tableau. Las visualizaciones de Tableau son especialmente útiles en los informes de estado para el cliente y los miembros del consejo. Para estos datos, cree un panel de Tableau que muestre un recuento simple de reclamaciones frente a opiniones, así como gráficos de barras apiladas de reclamaciones frente a opiniones para variables como recuentos de visualizaciones de vídeos, recuentos de "me gusta" de vídeos, recuentos de comparticiones de vídeos y recuentos de descargas de vídeos. Asegúrate de que sea fácil de entender para alguien que no sea un experto en datos, y recuerda que el subdirector es una persona con discapacidad visual.
#
# También recibes un correo electrónico de seguimiento de Willow Jaffey, responsable de ciencia de datos. Willow sugiere incluir un resumen ejecutivo de tu análisis para compartirlo con tus compañeros de equipo.
#
# Se ha estructurado y preparado un cuaderno para ayudarte en este proyecto. Por favor, complete las siguientes preguntas.

# %% [markdown]
# # **Proyecto fin de curso 3: Análisis exploratorio de datos**
#
# En esta actividad, examinará los datos proporcionados y los preparará para su análisis. También diseñará una visualización de datos profesional que cuente una historia y ayude a tomar decisiones basadas en datos para las necesidades empresariales.
#
# Tenga en cuenta que la actividad de visualización de Tableau es opcional y no afectará a la finalización del curso. Completar la actividad de Tableau le ayudará a practicar la planificación y el trazado de una visualización de datos basada en una necesidad empresarial específica. La estructura de esta actividad está diseñada para emular las propuestas que probablemente se le asignarán en su carrera como profesional de datos. Completar esta actividad le ayudará a prepararse para esos momentos profesionales.
# <br/>
#
# **El objetivo** de este proyecto es realizar un análisis exploratorio de datos sobre un conjunto de datos proporcionado. Tu misión es continuar la investigación que comenzaste en C2 y realizar más AED sobre estos datos con el objetivo de aprender más sobre las variables. De particular interés es la información relacionada con lo que distingue a los vídeos reivindicativos de los vídeos de opinión.
#
# **El objetivo** es explorar el conjunto de datos y crear visualizaciones.
# <br/>
# *Esta actividad consta de 4 partes:*
#
# **Parte 1:** Importaciones, enlaces y carga.
#
# **Parte 2:** Exploración de datos
# *   Limpieza de datos
#
# **Parte 3:** Construir visualizaciones
#
# **Parte 4:** Evaluar y compartir resultados

# %% [markdown]
# Siga las instrucciones y responda a la pregunta que figura a continuación para completar la actividad. A continuación, elaborará un resumen utilizando las preguntas que figuran en el Documento de Estrategia PACE.
#
# Asegúrese de completar esta actividad antes de continuar. El siguiente punto del curso le proporcionará un ejemplo completado para que lo compare con su propio trabajo.

# %% [markdown]
# # **Visualizar una historia en Tableau y Python**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# A lo largo de estos cuadernos de proyecto, verás referencias al marco de resolución de problemas PACE. Los siguientes componentes del cuaderno están etiquetados con la etapa PACE correspondiente: Planificar, Analizar, Construir y Ejecutar.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# Tenga en cuenta las preguntas de su Documento de Estrategia PACE y las que figuran a continuación, si procede, para elaborar su respuesta:
# 1. 1. Identifique los valores atípicos:
#
#
# * ¿Qué métodos son los mejores para identificar los valores atípicos?
# * ¿Cómo se toma la decisión de mantener o excluir los valores atípicos de cualquier modelo futuro?

# %% [markdown]
# **Pregunta 1** Creando visualizaciones como lo son los diagramas de cajas las estadisticas basicas
# **Pregunta 2** Dependiendo de tamaño de la muestra, entender lo datos

# %% [markdown]
# ### **Tarea 1. Importación, enlaces y carga**
# Ir a Tableau Public
# El siguiente enlace le ayudará a completar esta actividad. Mantenga Tableau Public abierto mientras realiza los siguientes pasos.
#
# Enlace a materiales de apoyo:
# Public Tableau: https://public.tableau.com/s/. Tenga en cuenta que el conjunto de datos TikTok se puede descargar directamente desde este cuaderno yendo a "Lab Files" en la barra de menú en la parte superior de la página, haciendo clic en la carpeta "/home/jovyan/work", seleccionando `tiktok_dataset.csv`, y haciendo clic en "Download" por encima de la lista de archivos.
#
# Para EDA de los datos, importar los paquetes que serían más útiles, como `pandas`, `numpy`, `matplotlib.pyplot`, y `seaborn`.

# %%
# Import packages for data manipulation
import numpy as np 
import pandas as pd

# Import packages for data visualization
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# A continuación, cargue el conjunto de datos en un marco de datos. Lee los datos y guárdalos como un objeto dataframe.
#
# **Nota:** Como se muestra en esta celda, el conjunto de datos se ha cargado automáticamente. No es necesario descargar el archivo .csv ni proporcionar más código para acceder al conjunto de datos y continuar con este laboratorio. Por favor, continúe con esta actividad completando las siguientes instrucciones.

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**
#
# Tenga en cuenta las preguntas de su Documento de Estrategia PACE y las que figuran a continuación cuando proceda para completar su código.

# %% [markdown]
# ### **Tarea 2a: Exploración y limpieza de datos**
#
# El primer paso es evaluar sus datos. Consulte la página Fuente de datos en Tableau Public para hacerse una idea del tamaño, la forma y la composición del conjunto de datos.
#
# Tenga en cuenta las funciones que le ayudarán a comprender y estructurar los datos.
#
# * `.head()`
# * `.info()`
# * `.describe()`
# * `.groupby()`
# * `.sort_values()`
#
# Considere las siguientes preguntas mientras trabaja:
#
# ¿Qué se hace con los datos que faltan (si los hay)?
#
# En este caso si hay datos faltantes pero como son muy pequeños no afecta la muestra y se pueden eliminar
#
# ¿Hay datos atípicos?
#
# si, existen datos atipicos

# %% [markdown]
# Empieza por descubrir, utilizando `.head()`, `.size` y `.shape`.

# %%
# Display and examine the first few rows of the dataframe
data.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# ...

# %%
# Get the size of the data
data.size
# Out:
# 232584

# %%
# Get the shape of the data
data.shape
# Out:
# (19382, 12)

# %% [markdown]
# Obtener información básica sobre los datos, utilizando `.info()`.

# %%
# Get basic information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# Generar una tabla de estadísticas descriptivas, utilizando `.describe()`.

# %%
# Generate a table of descriptive statistics
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
# datos nulos 
data.isnull().sum()
# Out:
# #                             0
# claim_status                298
# video_id                      0
# video_duration_sec            0
# video_transcription_text    298
# verified_status               0
# author_ban_status             0
# video_view_count            298
# video_like_count            298
# video_share_count           298
# video_download_count        298
# video_comment_count         298
# dtype: int64

# %% [markdown]
# ### **Tarea 2b. Evaluar los tipos de datos**

# %% [markdown]
# En Tableau, en la página de la fuente de datos, compruebe los tipos de datos de las columnas del conjunto de datos. Consulte las dimensiones y medidas en Tableau.

# %% [markdown]
# Revise las instrucciones enlazadas en el documento de Actividad anterior para crear la visualización de Tableau requerida.

# %% [markdown]
# ### **Tarea 2c. Seleccionar tipo(s) de visualización **

# %% [markdown]
# Seleccione los tipos de visualización de datos que le ayudarán a comprender y explicar los datos.
#
# Ahora que ya sabes qué columnas de datos vas a utilizar, es el momento de decidir qué visualización de datos tiene más sentido para el EDA del conjunto de datos de TikTok. ¿Qué tipo de visualización(es) de datos sería(n) más útil(s)? Considere la distribución de los datos.
#
# * Line graph
# * Bar chart
# * Box plot
# * Histogram
# * Heat map
# * Scatter plot
# * A geographic map

# %% [markdown]
# las visualizaciones mas utilies serian el diagrama de cajas(boxplot), mapa de calor  y el histograma

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
#
# Considere las preguntas de su Documento de estrategia PACE para reflexionar sobre la etapa de Construcción.

# %% [markdown]
# ### **Tarea 3. Crear visualizaciones**
#
# Ahora que ha evaluado sus datos, es hora de trazar sus visualizaciones.

# %% [markdown]
# #### **video_duration_sec**
#
# Cree un diagrama de caja para examinar la distribución de los valores en la columna `video_duration_sec`.

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
fig=plt.figure(figsize=(6,2))
plt.title('duracion de video en segundos ')
sns.boxplot(x=data["video_duration_sec"])

# %% [markdown]
# Cree un histograma de los valores de la columna `video_duration_sec` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
fig=plt.figure(figsize=(8,4))
ax=sns.histplot(x=data["video_duration_sec"],bins=range(0,61,5))
plt.title("duracion de video en segundos ")
# Out:
# Text(0.5, 1.0, 'duracion de video en segundos ')

# %% [markdown]
# **Pregunta:** ¿Qué notas en la duración y distribución de los vídeos?
#
#  Todos los vídeos duran entre 5 y 60 segundos, y la distribución es uniforme.

# %% [markdown]
# #### **conteo_vistas_video**  **video_view_count**
#
# Crea un gráfico de caja para examinar la dispersión de valores en la columna `video_view_count`.

# %%
# Create a boxplot to visualize distribution of `video_view_count`
fig=plt.figure(figsize=(5,2))
sns.boxplot(x=data["video_view_count"])
plt.title("Numero de vistas ")
# Out:
# Text(0.5, 1.0, 'Numero de vistas ')

# %% [markdown]
# Cree un histograma de los valores de la columna `video_view_count` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
fig=plt.figure(figsize=(8,6))
ax=sns.histplot(x=data["video_view_count"],bins=range(0,(10**6+1),10**5))
plt.title("histograma de visionado de vídeos")
# Out:
# Text(0.5, 1.0, 'histograma de visionado de vídeos')

# %% [markdown]
# **Pregunta:** ¿Qué observas en la distribución de esta variable?
#
#
# Esta variable tiene una distribución muy desigual, con más de la mitad de los vídeos recibiendo menos de 100.000 visualizaciones. La distribución del recuento de visionados > 100.000 visionados es uniforme.

# %% [markdown]
# #### **contar_vídeos_como**
#
# Crea un gráfico de cajas para examinar la dispersión de valores en la columna `video_like_count`.

# %%
# Create a boxplot to visualize distribution of `video_like_count`
fig=plt.figure(figsize=(18,2))
sns.boxplot(x=data["video_like_count"])
plt.title("Numero de likes ")
# Out:
# Text(0.5, 1.0, 'Numero de likes ')

# %% [markdown]
# Cree un histograma de los valores de la columna `video_like_count` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
ax = sns.histplot(data['video_like_count'], bins=range(0,(7*10**5+1),10**5))
plt.title('Vídeo como histograma de recuento');

# %% [markdown]
# **Pregunta:** ¿Qué observas en la distribución de esta variable?
#
# Al igual que en el recuento de visionados, hay muchos más vídeos con menos de 100.000 "me gusta" que con más. Sin embargo, en este caso, hay más de un estrechamiento, ya que los datos se inclinan hacia la derecha, con muchos vídeos en el extremo superior del recuento de me gusta.

# %% [markdown]
# #### **contar_comentarios_de_vídeo**
#
# Crea un gráfico de cajas para examinar la dispersión de valores en la columna `video_comment_count`.

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
plt.figure(figsize=(15,2))
plt.title('comentarios de videos')
sns.boxplot(x=data['video_comment_count']);

# %% [markdown]
# Cree un histograma de los valores de la columna `video_comment_count` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
plt.figure(figsize=(5,3))
sns.histplot(data['video_comment_count'], bins=range(0,(3001),100))
plt.title('Video de comentarios histogram');

# %% [markdown]
# **Pregunta:** ¿Qué observas en la distribución de esta variable?
#
# Una vez más, la gran mayoría de los vídeos se agrupan en la parte inferior del rango de valores para el recuento de comentarios de vídeo. La mayoría de los vídeos tienen menos de 100 comentarios. La distribución está muy sesgada a la derecha.

# %% [markdown]
# #### **recuento_de_vídeos_compartidos**
#
# Crear un gráfico de cajas para examinar la dispersión de los valores en la columna `video_share_count`.

# %%
# Create a boxplot to visualize distribution of `video_share_count`
plt.figure(figsize=(15,2))
plt.title('video compartido')
sns.boxplot(x=data['video_share_count']);

# %% [markdown]
# *Cree* un histograma de los valores de la columna `video_share_count` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
plt.figure(figsize=(6,4))
sns.histplot(data['video_share_count'], bins=range(0,(270001),10000))
plt.title('Video compartido histogram');

# %% [markdown]
# **Pregunta:** ¿Qué observas en la distribución de esta variable?
#
# La inmensa mayoría de los vídeos tienen menos de 10.000 visitas. La distribución está muy sesgada a la derecha.

# %% [markdown]
# #### **contar_descargas_vídeo**
#
# Crea un diagrama de cajas para examinar la dispersión de valores en la columna `video_download_count`.

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(15,2))
plt.title('Descarga de videos ')
sns.boxplot(x=data['video_download_count']);

# %% [markdown]
# Cree un histograma de los valores de la columna `video_download_count` para explorar más a fondo la distribución de esta variable.

# %%
# Create a histogram
plt.figure(figsize=(6,3))
sns.histplot(data['video_download_count'], bins=range(0,(15001),500))
plt.title('Video download count histogram');

# %% [markdown]
# **Pregunta:** ¿Qué observas en la distribución de esta variable?
#
# La mayoría de los vídeos se descargaron menos de 500 veces, pero algunos se descargaron más de 12.000 veces. Una vez más, los datos están muy sesgados a la derecha.

# %% [markdown]
# #### **Estado de la reclamación por estado de verificación**
#
# Ahora, cree un histograma con cuatro barras: una para cada combinación de estado de reclamación y estado de verificación.

# %%
# Create a histogram
plt.figure(figsize=(7,4))
sns.histplot(data=data,
             x='claim_status',
             hue='verified_status',
             multiple='dodge',
             shrink=0.9)
plt.title('histograma de reclamaciones por estado de verificación');

# %% [markdown]
# **Pregunta:** ¿Qué notas en el número de usuarios verificados en comparación con los no verificados? ¿Y cómo afecta eso a la probabilidad de que publiquen opiniones?
#
#  Hay muchos menos usuarios verificados que no verificados, pero si un usuario *está* verificado, es mucho más probable que publique opiniones.

# %% [markdown]
# #### **Estado de la reclamación por estado de prohibición del autor**
#
# El curso anterior utilizó una sentencia `groupby()` para examinar el recuento de cada estado de reclamación para cada estado de prohibición de autor. Ahora, usa un histograma para comunicar la misma información.

# %%
# Create a histogram
fig = plt.figure(figsize=(7,4))
sns.histplot(data, x='claim_status', hue='author_ban_status',
             multiple='dodge',
             hue_order=['active', 'under review', 'banned'],
             shrink=0.9,
             palette={'active':'green', 'under review':'orange', 'banned':'red'},
             alpha=0.5)
plt.title('Estado de las reclamaciones por autor Estado de prohibición - recuentos');

# %% [markdown]
# **Pregunta:** ¿Qué observa en el número de autores activos en comparación con los autores prohibidos, tanto para las reclamaciones como para las opiniones?
#
# a mediana de visionados de los autores no activos es mucho mayor que la mediana de visionados de los autores activos. Como se sabe que los autores no activos son más propensos a publicar reclamaciones, y que los vídeos de autores no activos obtienen muchas más visualizaciones en conjunto que los vídeos de autores activos, entonces `video_view_count` podría ser un buen indicador del estado de la reclamación.
#
# De hecho, una rápida comprobación de la mediana de visionados por estado de la reclamación confirma esta afirmación:

# %% [markdown]
# #### **Cuentas de vistas medias por estado de prohibición**
#
# Cree un gráfico de barras con tres barras: una para cada estado de prohibición de autor. La altura de cada barra debe corresponder a la mediana del número de visionados de todos los vídeos con ese estado de prohibición de autor.

# %%
# Create a bar plot
ban_status_counts = data.groupby(['author_ban_status']).median(
    numeric_only=True).reset_index()

fig = plt.figure(figsize=(5,3))
sns.barplot(data=ban_status_counts,
            x='author_ban_status',
            y='video_view_count',
            order=['active', 'under review', 'banned'],
            palette={'active':'green', 'under review':'orange', 'banned':'red'},
            alpha=0.5)
plt.title('Mediana de visitas por estado de prohibición');

# %% [markdown]
# **Pregunta:** ¿Qué observa en la mediana del número de visitas de los autores no activos en comparación con la de los autores activos? A partir de esa observación, ¿qué variable podría ser un buen indicador del estado de las reclamaciones?
#
# La mediana de visionados de los autores no activos es mucho mayor que la mediana de visionados de los autores activos. Como se sabe que los autores no activos son más propensos a publicar reclamaciones, y que los vídeos de autores no activos obtienen muchas más visualizaciones en conjunto que los vídeos de autores activos, entonces `video_view_count` podría ser un buen indicador del estado de la reclamación.
#
# De hecho, una rápida comprobación de la mediana de visionados por estado de la reclamación confirma esta afirmación:

# %%
# Calculate the median view count for claim status.
data.groupby('claim_status')['video_view_count'].median()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %% [markdown]
# #### **Vistas totales por estado de la reclamación**
#
# Cree un gráfico circular que represente las proporciones del total de visionados de los vídeos de reclamaciones y del total de visionados de los vídeos de opinión.

# %%
# Create a pie graph
fig = plt.figure(figsize=(3,3))
plt.pie(data.groupby('claim_status')['video_view_count'].sum(), labels=['claim', 'opinion'])
plt.title('Total views by video claim status');

# %% [markdown]
# **Pregunta:** ¿Qué observa en el recuento global de vistas sobre el estado de las reclamaciones?
#
# El recuento global de visionados está dominado por los vídeos reivindicativos, a pesar de que hay aproximadamente el mismo número de cada vídeo en el conjunto de datos.

# %% [markdown]
# ### **Task 4. Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if you were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis you've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# Nonetheless, it's good practice to get a sense of just how many of your data points could be considered outliers. The definition of an outlier can change based on the details of your project, and it helps to have domain expertise to decide a threshold. You've learned that a common way to determine outliers in a normal distribution is to calculate the interquartile range (IQR) and set a threshold that is 1.5 * IQR above the 3rd quartile.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.
#
# Write a for loop that iterates over the column names of each count variable. For each iteration:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"
#
# ```
# Example:
# Number of outliers, video_view_count: ___
# Number of outliers, video_like_count: ___
# Number of outliers, video_share_count: ___
# Number of outliers, video_download_count: ___
# Number of outliers, video_comment_count: ___
# ```

# %%
count_cols = ['video_view_count',
              'video_like_count',
              'video_share_count',
              'video_download_count',
              'video_comment_count',
              ]

for column in count_cols:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    median = data[column].median()
    outlier_threshold = median + 1.5*iqr

    # Count the number of values that exceed the outlier threshold
    outlier_count = (data[column] > outlier_threshold).sum()
    print(f'Number of outliers, {column}:', outlier_count)
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **Scatterplot**

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
sns.scatterplot(x=data["video_view_count"], y=data["video_like_count"],
                hue=data["claim_status"], s=10, alpha=.3)
plt.show()

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
opinion = data[data['claim_status']=='opinion']
sns.scatterplot(x=opinion["video_view_count"], y=opinion["video_like_count"],
                 s=10, alpha=.3)
plt.show()

# %% [markdown]
# También puede hacer un gráfico de dispersión en Tableau Public, que puede ser más fácil de manipular y presentar. Si desea instrucciones paso a paso, puede revisar las instrucciones enlazadas en la página de Actividad anterior.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# Considere las preguntas de su Documento de Estrategia PACE para reflexionar sobre la etapa Ejecutar.

# %% [markdown]
# ### **Task 5a. Results and evaluation**
#
# Having built visualizations in Tableau and in Python, what have you learned about the dataset? What other questions have your visualizations uncovered that you should pursue?
#
# ***Pro tip:*** Put yourself in your client's perspective, what would they want to know?
#
# Use the following code cells to pursue any additional EDA. Also use the space to make sure your visualizations are clean, easily understandable, and accessible.
#
# ***Ask yourself:*** Did you consider color, contrast, emphasis, and labeling?

# %% [markdown]
# **Respuesta ejemplar:**
#
# He aprendido ....
#
# * Examiné la distribución de los datos, las frecuencias de recuento, los valores medios y medianos, los valores extremos y los valores atípicos, los datos que faltaban, etc. Analicé las correlaciones entre variables, en particular entre la variable claim_status y otras. He analizado correlaciones entre variables, en particular entre la variable claim_status y otras.*
#
# Mis otras preguntas son ....
#
# * *Quiero investigar más a fondo las características distintivas que se aplican sólo a las reclamaciones o sólo a las opiniones. También quiero considerar otras variables que podrían ser útiles para comprender los datos.
#
# Mi cliente probablemente querría saber...
#
# *Mi cliente querría conocer las hipótesis sobre qué datos podrían ser predictivos de claim_status.*

# %% [markdown]
# ### **Tarea 5b. Conclusión**
# *Hazlo profesional y presentable*
#
# Ya has visualizado los datos que necesitas compartir con el director. Recuerda que el objetivo de una visualización de datos es que un miembro del público obtenga la información del gráfico en cuestión de segundos.
#
# **Pregúntate
# ¿Por qué es importante realizar un análisis exploratorio de datos? ¿Qué otras visualizaciones podrías crear?

# %% [markdown]
# EDA es importante porque ...
#
# * *EDA ayuda a un profesional de datos a conocer los datos, entender sus valores atípicos, limpiar sus valores perdidos y prepararlos para futuros modelados.*
#
# Las visualizaciones me ayudaron a comprender ..
#
# * *Que tendremos que tomar decisiones sobre ciertas consideraciones antes de diseñar un modelo. (por ejemplo, qué hacer con los valores atípicos, los valores duplicados o los datos que faltan)*.

# %% [markdown]
# Ahora has completado una visualización de datos profesional de acuerdo con una necesidad empresarial. Bien hecho. Asegúrese de guardar su trabajo como referencia para trabajos posteriores en Tableau.

# %% [markdown]
# **¡Felicidades!** Has completado este laboratorio. Sin embargo, es posible que no veas una marca de verificación verde junto a este elemento en la plataforma de Coursera. Por favor, continúa tu progreso independientemente de la marca de verificación. Simplemente haga clic en el icono "guardar" en la parte superior de este cuaderno para asegurarse de que su trabajo ha sido registrado.
